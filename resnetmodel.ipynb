# %%
import os
import cv2
import numpy as np

import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from PIL import Image

# %%
downloads_dir = "./data/downloads"
dataset_dir = "./data/dataset"
train_dir = dataset_dir + "/Data/Train"
valid_dir = dataset_dir + "/Data/Validation"
test_dir = dataset_dir + "/Data/Test"

# %%
os.makedirs(downloads_dir, exist_ok=True)
os.makedirs(dataset_dir, exist_ok=True)

# !wget "https://dl.dropboxusercontent.com/scl/fi/sm1mybj5a2v4ycrxbez7f/miniset.zip?rlkey=jwddeulszbudhbnjz3n70fj9f&st=ronsh841&dl=0" -O {downloads_dir}/minidataset.zip
#this is just a mini dataset to see if our code works or nah

# !unzip {downloads_dir}/minidataset.zip -d {dataset_dir}
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/dataset/Data/Test/B1H1_East/1102.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1116.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1088.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1158.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1206.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1165.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1172.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1189.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1200.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1161.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1175.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1203.png
#   inflating: ./data/dataset/Data/Test/B1H1_East/1029.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1031.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1024.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1146.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1027.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1153.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1143.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1037.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1156.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1034.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1020.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1126.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1132.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1085.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1119.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1092.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1051.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1044.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1078.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1054.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1068.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1041.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1082.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1109.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1095.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1136.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1122.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1098.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1112.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1058.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1071.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1065.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1105.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1139.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1115.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1129.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1061.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1075.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1048.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1102.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1088.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1170.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1010.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1004.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1173.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1007.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1166.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1017.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1163.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1149.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1014.png
#   inflating: ./data/dataset/Data/Test/B2H1_West/1160.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1634.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1581.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1595.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1557.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1543.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1423.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1437.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1619.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1547.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1552.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1591.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1432.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1624.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1418.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1586.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1495.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1442.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1456.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1480.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1643.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1509.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1524.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1519.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1653.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1490.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1447.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1533.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1452.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1485.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1476.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1648.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1528.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1500.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1514.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1461.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1471.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1538.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1504.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1658.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1466.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1428.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1629.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1615.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1576.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1562.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1600.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1610.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1567.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1639.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1605.png
#   inflating: ./data/dataset/Data/Test/B2H2_North/1571.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1191.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1146.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1153.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1184.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1209.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1037.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1142.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1156.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1181.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1195.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1132.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1047.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1125.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1086.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1079.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1051.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1044.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1093.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1118.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1040.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1054.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1068.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1096.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1082.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1121.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1135.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1107.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1072.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1058.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1065.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1111.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1139.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1061.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1075.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1128.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1100.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1114.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1089.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1103.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1170.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1212.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1198.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1167.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1205.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1163.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1177.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1188.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1149.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1202.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1216.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1174.png
#   inflating: ./data/dataset/Data/Test/B2H1_East/1160.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2505.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2498.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2513.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2275.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2260.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2304.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2475.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2461.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2267.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2312.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2349.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2215.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2572.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2200.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2438.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2565.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2401.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2416.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2364.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2371.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2208.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2394.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2431.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2237.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2223.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2579.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2550.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2356.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2342.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2408.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2193.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2386.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2379.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2423.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2557.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2230.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2542.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2446.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2334.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2297.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2527.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2282.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2453.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2490.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2319.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2245.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2483.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2468.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2520.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2252.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2535.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2290.png
#   inflating: ./data/dataset/Data/Test/B4H1_South/2327.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1151.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1227.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1193.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1185.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1231.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1219.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1147.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1143.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1235.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1208.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1181.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1154.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1223.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1196.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1250.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1292.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1319.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1131.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1284.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1246.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1281.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1242.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1323.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1135.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1296.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1269.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1254.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1311.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1265.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1258.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1304.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1273.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1307.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1139.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1288.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1277.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1128.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1300.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1261.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1315.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1158.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1170.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1212.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1239.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1204.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1166.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/1189.png
#   inflating: ./data/dataset/Data/Test/B1H2_North/
png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1024.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/956.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/940.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1032.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/982.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/986.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1036.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/944.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/978.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/952.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1009.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1021.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/990.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1047.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1086.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1051.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1044.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1078.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1093.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/936.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1124.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1120.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1097.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1040.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1055.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1082.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/933.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1109.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/929.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1066.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1112.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1070.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1059.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1105.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1101.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1074.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1116.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1089.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1063.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1005.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/963.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/975.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1013.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/948.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1017.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/971.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/959.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/998.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/967.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1001.png
#   inflating: ./data/dataset/Data/Validation/B1H2_North/1028.png

# %%
class ResNetClassifier(nn.Module):
    """
    Define ResNet model class
    """
    def __init__(self, num_classes):
        super(ResNetClassifier, self).__init__()
        self.resnet = models.resnet34(pretrained=True) #uses a pretrained resnet34 model from torchvision. testing 18
        #self.resnet.fc = nn.Linear(self.resnet.fc.in_features, num_classes) #change the classification fc layer to have the correct number of classes
        self.resnet.fc = nn.Sequential(
            nn.Dropout(p=0.5), #dropout layer to prevent overfitting. only of the fc layer tho, see if it does anything
            nn.Linear(self.resnet.fc.in_features, num_classes)
        )

    def forward(self, x):
        return self.resnet(x)

# %%
# Define a custom dataset for video frames
class VideoFrameDataset(Dataset):
    def __init__(self, frames, labels, transform=None):
        self.frames = frames  # list of frames as np arrays
        self.labels = labels  # corresponding labels for each frame
        self.transform = transform

    def __len__(self):
        return len(self.frames)

    def __getitem__(self, idx):
        frame = self.frames[idx]
        label = self.labels[idx]

        if isinstance(frame, np.ndarray):
            frame = Image.fromarray(frame)
        if self.transform:
            frame = self.transform(frame)

        #reverts frames to ndarray. ensures frames and labels are tensors so we can use .to(device)
        frame = torch.tensor(np.array(frame)).clone().detach().float()
        label = torch.tensor(label, dtype=torch.long)
        return frame, label

# %%
def load_data(directory):
    frames = []  # list of frames
    labels = []  # corresponding labels
    with os.scandir(directory) as folder_iterator:
        for folder in folder_iterator:
            if not folder.is_dir():
                continue
            label = folder.name
            with os.scandir(folder.path) as frame_iterator:
                for frame in frame_iterator:
                    if not frame.is_file() or not frame.name.lower().endswith('png'):
                        #if file is not png do not yield it
                        continue
                    image_path = os.path.join(folder.path, frame.name)
                    image = cv2.imread(image_path)
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  #by default cv2 reads in bgr
                    frames.append(image)  #appends an array
                    labels.append(label)

    # numerically convert labels
    label_encoder = LabelEncoder()
    labels = label_encoder.fit_transform(labels)
    return frames, labels

# %%
transform = transforms.Compose([transforms.ToTensor()])

train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=10),   # randomly rotate the image by up to 10 degrees
    transforms.RandomResizedCrop(size=(540, 960),   # final output image size
                                scale=(0.8, 1.0),   # selects a random scale of the original image, and crops image randomly to meet this scale
                                ratio=(9/16, 9/16)),# resize the image to 540x960 while maintaining aspect ratio
    transforms.ToTensor()
])

train_frames, train_labels = load_data(train_dir)
valid_frames, valid_labels = load_data(valid_dir)
test_frames, test_labels = load_data(test_dir)

#check if they should all be the same
train_dataset = VideoFrameDataset(train_frames, train_labels, transform=train_transforms)
train_dataload = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0) #workers to 0 for now because of multiprocessing issues

valid_dataset = VideoFrameDataset(valid_frames, valid_labels, transform=transform)
valid_dataload = DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=0)

test_dataset = VideoFrameDataset(test_frames, test_labels, transform=transform)
test_dataload = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)

num_classes = len(np.unique(train_labels))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResNetClassifier(num_classes=num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#figure out what inputs and labels looks like
for inputs,labels in train_dataload:
  print(inputs)
  print(labels)
  print(inputs.size())
  break
# Out:
# tensor([[[[0.4431, 0.4431, 0.4431,  ..., 0.6627, 0.6588, 0.6588],
#           [0.4471, 0.4471, 0.4471,  ..., 0.6627, 0.6588, 0.6588],
#           [0.4510, 0.4510, 0.4510,  ..., 0.6627, 0.6588, 0.6588],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.3647, 0.3647, 0.3608],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3686, 0.3647, 0.3647],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3608, 0.3569, 0.3569]],
#
#          [[0.3529, 0.3529, 0.3529,  ..., 0.5843, 0.5804, 0.5804],
#           [0.3569, 0.3569, 0.3569,  ..., 0.5843, 0.5804, 0.5804],
#           [0.3608, 0.3608, 0.3608,  ..., 0.5843, 0.5804, 0.5804],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.3059, 0.3059, 0.3020],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3098, 0.3059, 0.3059],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3020, 0.2980, 0.2980]],
#
#          [[0.2941, 0.2941, 0.2941,  ..., 0.5569, 0.5529, 0.5529],
#           [0.2980, 0.2980, 0.2980,  ..., 0.5569, 0.5529, 0.5529],
#           [0.3020, 0.3020, 0.3020,  ..., 0.5569, 0.5529, 0.5529],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.2627, 0.2627, 0.2588],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2667, 0.2627, 0.2627],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2667, 0.2627, 0.2627]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.4078, 0.4196, 0.4235],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3765, 0.3608, 0.3529],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2902, 0.2784, 0.2745]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.3529, 0.3647, 0.3686],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3255, 0.3098, 0.3020],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2392, 0.2275, 0.2235]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.3255, 0.3373, 0.3412],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2980, 0.2824, 0.2745],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2118, 0.2000, 0.1961]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.7176, 0.7098, 0.7020,  ..., 0.0000, 0.0000, 0.0000],
#           [0.7020, 0.7059, 0.7098,  ..., 0.0000, 0.0000, 0.0000],
#           [0.7098, 0.7098, 0.7059,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.6941, 0.6863, 0.6784,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6784, 0.6824, 0.6863,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6863, 0.6863, 0.6824,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.6627, 0.6549, 0.6471,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6471, 0.6510, 0.6549,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6549, 0.6549, 0.6510,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         ...,
#
#
#         [[[0.5451, 0.5451, 0.5412,  ..., 0.4824, 0.4824, 0.4824],
#           [0.5725, 0.5686, 0.5686,  ..., 0.4902, 0.4902, 0.4902],
#           [0.5922, 0.5922, 0.5961,  ..., 0.4941, 0.4902, 0.4902],
#           ...,
#           [0.3765, 0.3961, 0.4353,  ..., 0.6706, 0.6588, 0.6510],
#           [0.5059, 0.4745, 0.4157,  ..., 0.6275, 0.6235, 0.6235],
#           [0.4314, 0.4510, 0.4902,  ..., 0.5725, 0.5804, 0.5843]],
#
#          [[0.5098, 0.5098, 0.5059,  ..., 0.4510, 0.4510, 0.4510],
#           [0.5412, 0.5373, 0.5333,  ..., 0.4588, 0.4588, 0.4588],
#           [0.5569, 0.5608, 0.5608,  ..., 0.4627, 0.4588, 0.4588],
#           ...,
#           [0.3490, 0.3686, 0.4039,  ..., 0.6471, 0.6353, 0.6275],
#           [0.4745, 0.4431, 0.3843,  ..., 0.6039, 0.6000, 0.6000],
#           [0.4000, 0.4196, 0.4588,  ..., 0.5490, 0.5569, 0.5608]],
#
#          [[0.4196, 0.4196, 0.4196,  ..., 0.3843, 0.3843, 0.3843],
#           [0.4549, 0.4510, 0.4471,  ..., 0.3922, 0.3922, 0.3922],
#           [0.4706, 0.4745, 0.4745,  ..., 0.3961, 0.3922, 0.3922],
#           ...,
#           [0.3020, 0.3216, 0.3569,  ..., 0.6196, 0.6118, 0.6000],
#           [0.4275, 0.3961, 0.3373,  ..., 0.5804, 0.5765, 0.5725],
#           [0.3529, 0.3725, 0.4118,  ..., 0.5255, 0.5294, 0.5333]]],
#
#
#         [[[0.5294, 0.5294, 0.5294,  ..., 0.4941, 0.4941, 0.4941],
#           [0.5059, 0.5098, 0.5216,  ..., 0.4745, 0.4745, 0.4745],
#           [0.4745, 0.4863, 0.5137,  ..., 0.4706, 0.4706, 0.4706],
#           ...,
#           [0.6549, 0.6745, 0.7098,  ..., 0.7608, 0.7451, 0.7373],
#           [0.7216, 0.7294, 0.7451,  ..., 0.7608, 0.7412, 0.7255],
#           [0.7373, 0.7373, 0.7373,  ..., 0.7647, 0.7294, 0.7098]],
#
#          [[0.4941, 0.4941, 0.4941,  ..., 0.4588, 0.4549, 0.4549],
#           [0.4627, 0.4706, 0.4824,  ..., 0.4196, 0.4196, 0.4196],
#           [0.4275, 0.4431, 0.4706,  ..., 0.4000, 0.4000, 0.4000],
#           ...,
#           [0.6275, 0.6471, 0.6824,  ..., 0.7333, 0.7176, 0.7098],
#           [0.6941, 0.7020, 0.7176,  ..., 0.7333, 0.7137, 0.6980],
#           [0.7098, 0.7098, 0.7098,  ..., 0.7373, 0.7020, 0.6824]],
#
#          [[0.4784, 0.4784, 0.4784,  ..., 0.4510, 0.4471, 0.4471],
#           [0.4510, 0.4549, 0.4706,  ..., 0.4275, 0.4275, 0.4275],
#           [0.4196, 0.4314, 0.4627,  ..., 0.4275, 0.4275, 0.4275],
#           ...,
#           [0.6039, 0.6235, 0.6588,  ..., 0.7020, 0.6863, 0.6784],
#           [0.6706, 0.6784, 0.6941,  ..., 0.7020, 0.6824, 0.6667],
#           [0.6863, 0.6863, 0.6863,  ..., 0.7059, 0.6706, 0.6510]]],
#
#
#         [[[0.4314, 0.4314, 0.4314,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4941, 0.4980, 0.5020,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5490, 0.5529, 0.5569,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.6471, 0.6314, 0.6196],
#           [0.0000, 0.0000, 0.0000,  ..., 0.6510, 0.6353, 0.6235],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2588, 0.2549, 0.2549]],
#
#          [[0.4118, 0.4118, 0.4078,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4745, 0.4745, 0.4784,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5255, 0.5294, 0.5333,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.6196, 0.6039, 0.5961],
#           [0.0000, 0.0000, 0.0000,  ..., 0.6235, 0.6118, 0.6039],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2471, 0.2471, 0.2471]],
#
#          [[0.3804, 0.3843, 0.3843,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4431, 0.4471, 0.4510,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4941, 0.4980, 0.5020,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.6118, 0.5961, 0.5882],
#           [0.0000, 0.0000, 0.0000,  ..., 0.6157, 0.6000, 0.5922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2431, 0.2431, 0.2431]]]])
# tensor([ 2,  2, 14, 13,  0, 13, 13,  8, 15,  0,  0,  7,  5,  5, 12,  0, 14, 11,
#          5, 10,  5, 13,  5,  6, 10, 11,  2,  4,  3, 12,  8, 14])
# torch.Size([32, 3, 540, 960])

# %%
for inputs,labels in valid_dataload:
  print(inputs)
  print(labels)
  print(inputs.size())
  break
# Out:
# tensor([[[[0.7725, 0.5216, 0.3686,  ..., 0.5686, 0.5686, 0.5725],
#           [0.8039, 0.4941, 0.3608,  ..., 0.5686, 0.5686, 0.5686],
#           [0.7725, 0.5529, 0.3490,  ..., 0.5686, 0.5647, 0.5647],
#           ...,
#           [0.7098, 0.7412, 0.5922,  ..., 0.5176, 0.5569, 0.6980],
#           [0.7216, 0.7333, 0.5961,  ..., 0.6078, 0.5216, 0.6353],
#           [0.7137, 0.7059, 0.6667,  ..., 0.7294, 0.5922, 0.5294]],
#
#          [[0.8275, 0.5882, 0.3529,  ..., 0.5451, 0.5451, 0.5490],
#           [0.8353, 0.5059, 0.3451,  ..., 0.5451, 0.5451, 0.5451],
#           [0.8471, 0.5412, 0.3333,  ..., 0.5451, 0.5412, 0.5412],
#           ...,
#           [0.7804, 0.7451, 0.5765,  ..., 0.5020, 0.5333, 0.6745],
#           [0.7843, 0.7490, 0.5804,  ..., 0.5922, 0.5059, 0.6157],
#           [0.7490, 0.7333, 0.6510,  ..., 0.7137, 0.5765, 0.5098]],
#
#          [[0.8078, 0.5608, 0.3216,  ..., 0.4980, 0.4980, 0.5020],
#           [0.8118, 0.4784, 0.3137,  ..., 0.4980, 0.4980, 0.4980],
#           [0.8275, 0.5176, 0.3059,  ..., 0.4980, 0.4941, 0.4941],
#           ...,
#           [0.7569, 0.7255, 0.5490,  ..., 0.4784, 0.5137, 0.6549],
#           [0.7608, 0.7255, 0.5529,  ..., 0.5686, 0.4863, 0.5961],
#           [0.7255, 0.7137, 0.6235,  ..., 0.6902, 0.5569, 0.4902]]],
#
#
#         [[[0.7725, 0.5804, 0.4745,  ..., 0.6745, 0.6392, 0.6157],
#           [0.8039, 0.5529, 0.4745,  ..., 0.6353, 0.5961, 0.5686],
#           [0.7725, 0.6196, 0.4745,  ..., 0.5765, 0.5255, 0.4941],
#           ...,
#           [0.7098, 0.7333, 0.6235,  ..., 0.6157, 0.6392, 0.6157],
#           [0.7216, 0.7373, 0.6118,  ..., 0.6431, 0.6902, 0.5961],
#           [0.7137, 0.7059, 0.6039,  ..., 0.6667, 0.7137, 0.6039]],
#
#          [[0.8275, 0.6392, 0.4510,  ..., 0.6549, 0.6196, 0.5961],
#           [0.8353, 0.5608, 0.4510,  ..., 0.6157, 0.5765, 0.5490],
#           [0.8471, 0.6039, 0.4510,  ..., 0.5569, 0.5059, 0.4745],
#           ...,
#           [0.7804, 0.7412, 0.6078,  ..., 0.6000, 0.6235, 0.5961],
#           [0.7843, 0.7529, 0.5961,  ..., 0.6275, 0.6706, 0.5765],
#           [0.7490, 0.7333, 0.5882,  ..., 0.6510, 0.6941, 0.5843]],
#
#          [[0.8078, 0.6157, 0.4314,  ..., 0.6667, 0.6314, 0.6118],
#           [0.8118, 0.5373, 0.4314,  ..., 0.6275, 0.5882, 0.5608],
#           [0.8275, 0.5804, 0.4314,  ..., 0.5686, 0.5176, 0.4863],
#           ...,
#           [0.7569, 0.7294, 0.6000,  ..., 0.5804, 0.6078, 0.5843],
#           [0.7608, 0.7412, 0.5882,  ..., 0.6078, 0.6549, 0.5647],
#           [0.7255, 0.7216, 0.5804,  ..., 0.6314, 0.6784, 0.5725]]],
#
#
#         [[[0.7725, 0.6667, 0.6667,  ..., 0.8157, 0.8235, 0.8196],
#           [0.8039, 0.6431, 0.6353,  ..., 0.8196, 0.8235, 0.8196],
#           [0.7725, 0.7137, 0.6510,  ..., 0.8235, 0.8235, 0.8118],
#           ...,
#           [0.7098, 0.6627, 0.4706,  ..., 0.5020, 0.4549, 0.4235],
#           [0.7216, 0.6667, 0.4863,  ..., 0.5529, 0.4745, 0.4157],
#           [0.7137, 0.6549, 0.5020,  ..., 0.5647, 0.5059, 0.4431]],
#
#          [[0.8275, 0.7294, 0.6549,  ..., 0.8039, 0.8118, 0.8078],
#           [0.8353, 0.6510, 0.6157,  ..., 0.8078, 0.8118, 0.8078],
#           [0.8471, 0.6941, 0.6275,  ..., 0.8118, 0.8118, 0.7961],
#           ...,
#           [0.7804, 0.6667, 0.4510,  ..., 0.4824, 0.4314, 0.4000],
#           [0.7843, 0.6824, 0.4667,  ..., 0.5333, 0.4549, 0.3922],
#           [0.7490, 0.6824, 0.4824,  ..., 0.5451, 0.4824, 0.4196]],
#
#          [[0.8078, 0.6980, 0.6118,  ..., 0.7804, 0.7843, 0.7843],
#           [0.8118, 0.6235, 0.5804,  ..., 0.7843, 0.7882, 0.7843],
#           [0.8275, 0.6667, 0.6000,  ..., 0.7882, 0.7843, 0.7686],
#           ...,
#           [0.7569, 0.6392, 0.4118,  ..., 0.4431, 0.3882, 0.3608],
#           [0.7608, 0.6549, 0.4275,  ..., 0.4941, 0.4118, 0.3529],
#           [0.7255, 0.6549, 0.4431,  ..., 0.5059, 0.4392, 0.3804]]],
#
#
#         ...,
#
#
#         [[[0.7725, 0.5804, 0.4745,  ..., 0.3490, 0.3176, 0.2667],
#           [0.8039, 0.5569, 0.4784,  ..., 0.3608, 0.3294, 0.2824],
#           [0.7725, 0.6235, 0.4863,  ..., 0.3137, 0.3137, 0.3059],
#           ...,
#           [0.7098, 0.7333, 0.5647,  ..., 0.7098, 0.6588, 0.6235],
#           [0.7216, 0.7255, 0.5529,  ..., 0.7333, 0.6863, 0.6392],
#           [0.7137, 0.6941, 0.5373,  ..., 0.7373, 0.7098, 0.6549]],
#
#          [[0.8275, 0.6431, 0.4549,  ..., 0.3294, 0.2980, 0.2471],
#           [0.8353, 0.5647, 0.4588,  ..., 0.3412, 0.3098, 0.2627],
#           [0.8471, 0.6118, 0.4667,  ..., 0.2941, 0.2941, 0.2863],
#           ...,
#           [0.7804, 0.7451, 0.5529,  ..., 0.6941, 0.6431, 0.6078],
#           [0.7843, 0.7451, 0.5412,  ..., 0.7176, 0.6706, 0.6235],
#           [0.7490, 0.7255, 0.5255,  ..., 0.7216, 0.6941, 0.6392]],
#
#          [[0.8078, 0.6275, 0.4510,  ..., 0.3412, 0.3098, 0.2627],
#           [0.8118, 0.5529, 0.4549,  ..., 0.3529, 0.3216, 0.2745],
#           [0.8275, 0.5961, 0.4627,  ..., 0.3059, 0.3059, 0.2980],
#           ...,
#           [0.7569, 0.7255, 0.5333,  ..., 0.6706, 0.6157, 0.5843],
#           [0.7608, 0.7255, 0.5216,  ..., 0.6941, 0.6431, 0.6000],
#           [0.7255, 0.7059, 0.5059,  ..., 0.6980, 0.6706, 0.6157]]],
#
#
#         [[[0.7725, 0.5647, 0.4431,  ..., 0.5098, 0.5098, 0.6039],
#           [0.8039, 0.5451, 0.4431,  ..., 0.5176, 0.5176, 0.5373],
#           [0.7725, 0.6235, 0.4588,  ..., 0.5255, 0.5255, 0.5020],
#           ...,
#           [0.7098, 0.6745, 0.5333,  ..., 0.5294, 0.5882, 0.6314],
#           [0.7216, 0.6902, 0.5569,  ..., 0.5020, 0.5569, 0.6039],
#           [0.7137, 0.6863, 0.5686,  ..., 0.4902, 0.5373, 0.5765]],
#
#          [[0.8275, 0.6157, 0.4000,  ..., 0.4706, 0.4706, 0.5647],
#           [0.8353, 0.5412, 0.4000,  ..., 0.4784, 0.4784, 0.4980],
#           [0.8471, 0.5961, 0.4157,  ..., 0.4863, 0.4863, 0.4627],
#           ...,
#           [0.7804, 0.6745, 0.5098,  ..., 0.5020, 0.5608, 0.6039],
#           [0.7843, 0.7020, 0.5333,  ..., 0.4745, 0.5294, 0.5765],
#           [0.7490, 0.7098, 0.5451,  ..., 0.4627, 0.5098, 0.5490]],
#
#          [[0.8078, 0.5765, 0.3490,  ..., 0.4078, 0.4078, 0.5020],
#           [0.8118, 0.5059, 0.3490,  ..., 0.4157, 0.4157, 0.4353],
#           [0.8275, 0.5569, 0.3647,  ..., 0.4235, 0.4235, 0.4000],
#           ...,
#           [0.7569, 0.6510, 0.4784,  ..., 0.4706, 0.5294, 0.5765],
#           [0.7608, 0.6784, 0.5020,  ..., 0.4431, 0.4980, 0.5490],
#           [0.7255, 0.6863, 0.5137,  ..., 0.4314, 0.4824, 0.5216]]],
#
#
#         [[[0.7725, 0.6078, 0.5294,  ..., 0.5804, 0.5765, 0.5804],
#           [0.8039, 0.5765, 0.5255,  ..., 0.5765, 0.5765, 0.5765],
#           [0.7725, 0.6392, 0.5176,  ..., 0.5843, 0.5804, 0.5804],
#           ...,
#           [0.7098, 0.7843, 0.6863,  ..., 0.6627, 0.5412, 0.4588],
#           [0.7216, 0.7961, 0.7020,  ..., 0.6667, 0.5412, 0.4706],
#           [0.7137, 0.7804, 0.7176,  ..., 0.6706, 0.5373, 0.4745]],
#
#          [[0.8275, 0.6667, 0.5020,  ..., 0.5569, 0.5569, 0.5608],
#           [0.8353, 0.5843, 0.4980,  ..., 0.5529, 0.5529, 0.5529],
#           [0.8471, 0.6235, 0.4941,  ..., 0.5529, 0.5529, 0.5529],
#           ...,
#           [0.7804, 0.7922, 0.6706,  ..., 0.6471, 0.5255, 0.4392],
#           [0.7843, 0.8118, 0.6863,  ..., 0.6510, 0.5216, 0.4471],
#           [0.7490, 0.8078, 0.7020,  ..., 0.6549, 0.5216, 0.4549]],
#
#          [[0.8078, 0.6510, 0.4941,  ..., 0.4980, 0.5020, 0.5020],
#           [0.8118, 0.5686, 0.4902,  ..., 0.4941, 0.4980, 0.4980],
#           [0.8275, 0.6078, 0.4824,  ..., 0.4980, 0.4980, 0.4980],
#           ...,
#           [0.7569, 0.7725, 0.6471,  ..., 0.6275, 0.5059, 0.4235],
#           [0.7608, 0.7922, 0.6627,  ..., 0.6314, 0.5059, 0.4314],
#           [0.7255, 0.7882, 0.6784,  ..., 0.6353, 0.5020, 0.4392]]]])
# tensor([13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#         13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13])
# torch.Size([32, 3, 960, 540])

# %%
def evaluate_model(model, dataloader, criterion):
    """
    Evaluates a trained model given a validation/test dataloader

    Input:
    model: the model we would like to train
    dataloader: the data
    criterion: the loss function used to determine loss
    optimizer: the optimizer used in backpropagation
    num_epochs: the number of epochs we train for


    Output:
    the loss and accuracy
    """
    model.eval()

    running_loss = 0.0
    accurate_pred = 0
    total_pred = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            accurate_pred += (predicted == labels).sum().item()
            total_pred += labels.size(0)

    avg_loss = running_loss/total_pred
    accuracy = accurate_pred/total_pred

    return avg_loss, accuracy

# %%
def train_model(model, train_dataload, valid_dataload, criterion, optimizer, num_epochs=25):
    """
    Trains a given model over a given number of epochs. Default set to 25.

    Input:
    model: the model we would like to train
    dataloader: the data
    criterion: the loss function used to determine loss
    optimizer: the optimizer used in backpropagation
    num_epochs: the number of epochs we train for


    Output:
    a trained model
    """
    best_val_loss = float('inf')

    stored_accloss = []

    scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)


    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_dataload:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(train_dataload.dataset)

        valid_loss, valid_acc = evaluate_model(model, valid_dataload, criterion)

        stored_accloss.append((epoch_loss, valid_loss, valid_acc))

        if valid_loss < best_val_loss:
            best_val_loss = valid_loss
            torch.save(model.state_dict(), 'best_model.pth')

        print(f'Epoch {epoch}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Valid Loss: {valid_loss:.4f}, Valid Accuracy {valid_acc:.4f}')

        scheduler.step()


    #plot the acc and losses
    plt.plot([x[0] for x in stored_accloss], label='Train Loss')
    plt.plot([x[1] for x in stored_accloss], label='Valid Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

    plt.plot([x[2] for x in stored_accloss], label='Valid Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Validation Accuracy')
    plt.show()

    return model

# %%
trained_model = train_model(model, train_dataload, valid_dataload, criterion, optimizer, num_epochs=25)
# Out:
# Epoch 0/25, Train Loss: 0.5275, Valid Loss: 1.4496, Valid Accuracy 0.4694
# Epoch 1/25, Train Loss: 0.0227, Valid Loss: 1.4145, Valid Accuracy 0.4526
# Epoch 2/25, Train Loss: 0.0095, Valid Loss: 1.2812, Valid Accuracy 0.5318
# Epoch 3/25, Train Loss: 0.0045, Valid Loss: 1.2966, Valid Accuracy 0.5162
# Epoch 4/25, Train Loss: 0.0035, Valid Loss: 1.3397, Valid Accuracy 0.5006
# Epoch 5/25, Train Loss: 0.0024, Valid Loss: 1.3073, Valid Accuracy 0.5030
# Epoch 6/25, Train Loss: 0.0018, Valid Loss: 1.3168, Valid Accuracy 0.5318
# Epoch 7/25, Train Loss: 0.0014, Valid Loss: 1.3289, Valid Accuracy 0.5018
# Epoch 8/25, Train Loss: 0.0090, Valid Loss: 1.8857, Valid Accuracy 0.3541
# Epoch 9/25, Train Loss: 0.0243, Valid Loss: 1.3724, Valid Accuracy 0.4814
# Epoch 10/25, Train Loss: 0.0045, Valid Loss: 1.3448, Valid Accuracy 0.4430
# Epoch 11/25, Train Loss: 0.0029, Valid Loss: 1.2848, Valid Accuracy 0.4778

# %%
#evaluate with test set
model.load_state_dict(torch.load('best_model.pth'))
test_loss, test_accuracy = evaluate_model(model, test_dataload, criterion)

print(f'Test Loss: {test_loss:.4f}, Test Accuracy {test_accuracy:.4f}') #its over fit
# Out:
# Test Loss: 1.8025, Test Accuracy 0.3825

# %%
torch.save(model, 'downloadable_best_model.pth')
